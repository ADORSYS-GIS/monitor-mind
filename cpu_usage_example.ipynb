# %% [markdown]
# # Showcase of the CPU service

# %% [markdown]
# Importing the service

# %%
from services.cpu_service import calculate_cpu_usage, get_cpu_usage_array

# %% [markdown]
# Get CPU usage

# %%
import sys
sys.path.append('/home/bryan/disk_space/monitor-mind/services/')

import psutil


def get_disk_space():
    partitions = psutil.disk_partitions()
    disk_info = []
    # This portion of the code is used to check Disk Usage and Availability Information
    # Check Disk Usage Information
    print("                       ")
    print("Disk Usage Information") 
    print("------------------------")
    disk_usage = psutil.disk_usage('/')
    print(f"Total: {disk_usage.total}")
    print(f"Used: {disk_usage.used}")
    print(f"Free: {disk_usage.free}")
    print(f"Percentage Used: {disk_usage.percent}%")

    return disk_info
    
def calculate_cpu_usage():
    cpu_percent = psutil.cpu_percent(interval=1)
    return cpu_percent

disk_space = get_disk_space()

# Check Disk Availability Information
print("                             ")
print("Disk Availability Information")
print("------------------------------")
disk_avail = psutil.disk_partitions()
for partition in disk_avail:
    print(f"Device: {partition.device}")
    print(f"Mountpoint: {partition.mountpoint}")
    print(f"Filesystem: {partition.fstype}")
    print(f"Options: {partition.opts}")
    print("----------------------------------------------------------------------------")



cpu_usage = calculate_cpu_usage()
print(f"CPU Usage: {cpu_usage}%")
# Out:
#
# Disk Usage Information
# ------------------------
# Total: 490574913536
# Used: 82540109824
# Free: 383039688704
# Percentage Used: 17.7%
#
# Disk Availability Information
# ------------------------------
# Device: /dev/sda3
# Mountpoint: /
# Filesystem: ext4
# Options: rw,relatime,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/loop0
# Mountpoint: /snap/bare/5
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop1
# Mountpoint: /snap/cloud-gaming-demo/19
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop2
# Mountpoint: /snap/code/144
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop3
# Mountpoint: /snap/code/145
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop5
# Mountpoint: /snap/core/16202
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop6
# Mountpoint: /snap/core18/2790
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop4
# Mountpoint: /snap/core/16091
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop11
# Mountpoint: /snap/core22/864
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop13
# Mountpoint: /snap/firefox/3252
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop16
# Mountpoint: /snap/firefox/3290
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop22
# Mountpoint: /snap/jq/6
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop19
# Mountpoint: /snap/gnome-42-2204/141
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop9
# Mountpoint: /snap/core20/2015
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop7
# Mountpoint: /snap/core18/2796
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop24
# Mountpoint: /snap/notion-snap-reborn/20
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop25
# Mountpoint: /snap/qt515-core20/28
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop17
# Mountpoint: /snap/gnome-3-38-2004/143
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop8
# Mountpoint: /snap/core20/1974
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop10
# Mountpoint: /snap/core22/858
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop12
# Mountpoint: /snap/discord/161
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop23
# Mountpoint: /snap/multipass/10244
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop27
# Mountpoint: /snap/snap-store/959
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop20
# Mountpoint: /snap/gtk-common-themes/1535
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop15
# Mountpoint: /snap/gnome-3-28-1804/198
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop21
# Mountpoint: /snap/htop/3873
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop29
# Mountpoint: /snap/snapd/20290
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop18
# Mountpoint: /snap/gnome-42-2204/132
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop30
# Mountpoint: /snap/snapd-desktop-integration/83
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop32
# Mountpoint: /snap/tree/18
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop26
# Mountpoint: /snap/share/20
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop28
# Mountpoint: /snap/snapd/20092
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop33
# Mountpoint: /snap/vlc/3078
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop36
# Mountpoint: /snap/wifiattendance/2
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop35
# Mountpoint: /snap/whatsie/146
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop34
# Mountpoint: /snap/vlc/3721
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop31
# Mountpoint: /snap/telegram-desktop/5133
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop37
# Mountpoint: /snap/whatsapp-for-linux/58
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/sda3
# Mountpoint: /var/snap/firefox/common/host-hunspell
# Filesystem: ext4
# Options: ro,noexec,noatime,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/sda2
# Mountpoint: /boot/efi
# Filesystem: vfat
# Options: rw,relatime,fmask=0077,dmask=0077,codepage=437,iocharset=iso8859-1,shortname=mixed,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/loop38
# Mountpoint: /snap/discord/162
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop39
# Mountpoint: /snap/telegram-desktop/5204
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop40
# Mountpoint: /snap/notion-snap-reborn/21
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# CPU Usage: 19.2%

# %% [markdown]
# Get CPU usage array

# %%
import sys
sys.path.append('/home/bryan/disk_space/monitor-mind/services/')

import psutil

def get_disk_space():
    partitions = psutil.disk_partitions()
    disk_info = []
    # This portion of the code is used to check Disk Usage and Availability Information
    # Check Disk Usage Information
    print("                       ")
    print("Disk Usage Information")
    print("------------------------")
    disk_usage = psutil.disk_usage('/')
    print(f"Total: {disk_usage.total}")
    print(f"Used: {disk_usage.used}")
    print(f"Free: {disk_usage.free}")
    print(f"Percentage Used: {disk_usage.percent}%")

    return disk_info

def get_cpu_usage_array():
    cpu_percentages = psutil.cpu_percent(interval=1, percpu=True)
    return cpu_percentages

disk_space = get_disk_space()

# Check Disk Availability Information
print("                             ")
print("Disk Availability Information")
print("------------------------------")
disk_avail = psutil.disk_partitions()
for partition in disk_avail:
    print(f"Device: {partition.device}")
    print(f"Mountpoint: {partition.mountpoint}")
    print(f"Filesystem: {partition.fstype}")
    print(f"Options: {partition.opts}")
    print("----------------------------------------------------------------------------")


cpu_usage_array = get_cpu_usage_array()
print("CPU Usage Array:")
if cpu_usage_array:
    print(cpu_usage_array[0])
# Out:
#
# Disk Usage Information
# ------------------------
# Total: 490574913536
# Used: 82540277760
# Free: 383039520768
# Percentage Used: 17.7%
#
# Disk Availability Information
# ------------------------------
# Device: /dev/sda3
# Mountpoint: /
# Filesystem: ext4
# Options: rw,relatime,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/loop0
# Mountpoint: /snap/bare/5
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop1
# Mountpoint: /snap/cloud-gaming-demo/19
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop2
# Mountpoint: /snap/code/144
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop3
# Mountpoint: /snap/code/145
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop5
# Mountpoint: /snap/core/16202
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop6
# Mountpoint: /snap/core18/2790
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop4
# Mountpoint: /snap/core/16091
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop11
# Mountpoint: /snap/core22/864
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop13
# Mountpoint: /snap/firefox/3252
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop16
# Mountpoint: /snap/firefox/3290
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop22
# Mountpoint: /snap/jq/6
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop19
# Mountpoint: /snap/gnome-42-2204/141
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop9
# Mountpoint: /snap/core20/2015
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop7
# Mountpoint: /snap/core18/2796
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop24
# Mountpoint: /snap/notion-snap-reborn/20
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop25
# Mountpoint: /snap/qt515-core20/28
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop17
# Mountpoint: /snap/gnome-3-38-2004/143
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop8
# Mountpoint: /snap/core20/1974
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop10
# Mountpoint: /snap/core22/858
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop12
# Mountpoint: /snap/discord/161
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop23
# Mountpoint: /snap/multipass/10244
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop27
# Mountpoint: /snap/snap-store/959
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop20
# Mountpoint: /snap/gtk-common-themes/1535
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop15
# Mountpoint: /snap/gnome-3-28-1804/198
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop21
# Mountpoint: /snap/htop/3873
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop29
# Mountpoint: /snap/snapd/20290
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop18
# Mountpoint: /snap/gnome-42-2204/132
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop30
# Mountpoint: /snap/snapd-desktop-integration/83
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop32
# Mountpoint: /snap/tree/18
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop26
# Mountpoint: /snap/share/20
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop28
# Mountpoint: /snap/snapd/20092
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop33
# Mountpoint: /snap/vlc/3078
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop36
# Mountpoint: /snap/wifiattendance/2
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop35
# Mountpoint: /snap/whatsie/146
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop34
# Mountpoint: /snap/vlc/3721
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop31
# Mountpoint: /snap/telegram-desktop/5133
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop37
# Mountpoint: /snap/whatsapp-for-linux/58
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/sda3
# Mountpoint: /var/snap/firefox/common/host-hunspell
# Filesystem: ext4
# Options: ro,noexec,noatime,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/sda2
# Mountpoint: /boot/efi
# Filesystem: vfat
# Options: rw,relatime,fmask=0077,dmask=0077,codepage=437,iocharset=iso8859-1,shortname=mixed,errors=remount-ro
# ----------------------------------------------------------------------------
# Device: /dev/loop38
# Mountpoint: /snap/discord/162
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop39
# Mountpoint: /snap/telegram-desktop/5204
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# Device: /dev/loop40
# Mountpoint: /snap/notion-snap-reborn/21
# Filesystem: squashfs
# Options: ro,nodev,relatime,errors=continue,threads=single
# ----------------------------------------------------------------------------
# CPU Usage Array:
# 18.6
